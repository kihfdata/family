# %% [markdown]
# <a href="https://colab.research.google.com/github/kihfdata/family/blob/main/Colaboratory_empty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
